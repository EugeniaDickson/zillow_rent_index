# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Zillow ZRI

# %%
main_dataframe = pd.read_csv('../../data/zillow/Zip_Zri_MultiFamilyResidenceRental.csv', dtype = {'RegionName':str})
main_dataframe.rename(columns = {'RegionName':'Zipcode'}, inplace = True)
main_dataframe['Zipcode'] = main_dataframe['Zipcode'].str.zfill(5)

# %%
main_dataframe = pd.melt(main_dataframe, id_vars =main_dataframe.columns[:7],
                         value_vars = main_dataframe.columns[7:],
                         var_name = 'Date', 
                         value_name = 'Rent')
main_dataframe['Date'] = pd.to_datetime(main_dataframe['Date'])

# %%
fill_rents = main_dataframe[['Zipcode', 'Rent', 'Date']].copy()
# zori_sf_metro.drop('Rent', axis = 1, inplace = True)

fill_rents = fill_rents.reset_index().pivot(index = 'Date',columns = 'Zipcode')['Rent'].reset_index()
for code in fill_rents.columns[1:]:
     fill_rents[code].interpolate(inplace = True)
fill_rents.fillna(method = 'bfill',inplace = True)
fill_rents = pd.melt(fill_rents, id_vars='Date', 
                                  value_vars = fill_rents.columns[1:],
                                  var_name='Zipcode',value_name = 'Rent')

main_dataframe.drop('Rent', axis = 1, inplace = True)
main_dataframe = pd.merge(main_dataframe, fill_rents, on = ['Date','Zipcode'])

# %%
main_dataframe.isnull().sum()
# Out:
# RegionID        0
# Zipcode         0
# City            0
# State           0
# Metro         339
# CountyName      0
# SizeRank        0
# Date            0
# Rent            0
# dtype: int64

# %%
main_dataframe['Year'] = main_dataframe['Date'].dt.year
main_dataframe
# Out:
#         RegionID Zipcode            City State  \
# 0          61639   10025        New York    NY
# 1          84654   60657         Chicago    IL
# 2          61637   10023        New York    NY
# 3          91982   77494            Katy    TX
# 4          84616   60614         Chicago    IL
# ...          ...     ...             ...   ...
# 210288     90755   75202          Dallas    TX
# 210289     94610   84627         Ephraim    UT
# 210290     84452   60301        Oak Park    IL
# 210291     94629   84647  Mount Pleasant    UT
# 210292     91695   77046         Houston    TX
#
#                                    Metro       CountyName  SizeRank  \
# 0            New York-Newark-Jersey City  New York County         1
# 1               Chicago-Naperville-Elgin      Cook County         2
# 2            New York-Newark-Jersey City  New York County         3
# 3       Houston-The Woodlands-Sugar Land    Harris County         4
# 4               Chicago-Naperville-Elgin      Cook County         5
# ...                                  ...              ...       ...
# 210288       Dallas-Fort Worth-Arlington    Dallas County      1857
# 210289                               NaN   Sanpete County      1858
# 210290          Chicago-Naperville-Elgin      Cook County      1859
# 210291                               NaN   Sanpete County      1860
# 210292  Houston-The Woodlands-Sugar Land    Harris County      1861
#
#              Date    Rent  Year
# 0      2010-09-01  2930.0  2010
# 1      2010-09-01  1447.0  2010
# 2      2010-09-01  2797.0  2010
# 3      2010-09-01  1081.0  2010
# 4      2010-09-01  1437.0  2010
# ...           ...     ...   ...
# 210288 2020-01-01  1739.0  2020
# 210289 2020-01-01  1298.0  2020
# 210290 2020-01-01  1625.0  2020
# 210291 2020-01-01  1221.0  2020
# 210292 2020-01-01  1398.0  2020
#
# [210293 rows x 10 columns]

# %% [markdown]
# ## Air Quality

# %%
fpath = '../../data/airqual/'
cols = ['Date Local','Arithmetic Mean','State Name', 'County Name', 'City Name']
file_list = [(f'{fpath}/daily_42602_{year}.csv') for year in range(2010, 2021)]
dataframe = pd.read_csv(file_list[0], usecols = cols)

# %%
file_list = [(f'{fpath}/daily_42602_{year}.csv') for year in range(2010, 2021)]
cols = ['Date Local', 'Arithmetic Mean', 'State Name', 'County Name', 'City Name']

dataframe = pd.read_csv(file_list[0], usecols = cols)

for file in file_list[1:]:
    new_df = pd.read_csv(file, usecols = cols)
    dataframe = pd.concat([dataframe, new_df], axis=0)

# %%
dataframe['Date Local'] = pd.to_datetime(dataframe['Date Local'])
dataframe['Month'] = dataframe['Date Local'].dt.month
dataframe['Year'] = dataframe['Date Local'].dt.year
dataframe = dataframe.groupby(['State Name', 'County Name', 'City Name', 'Year', 'Month'])[['Arithmetic Mean']].agg('mean').reset_index()
dataframe.Month = dataframe.Month.astype(str)
dataframe.Month = dataframe.Month.str.zfill(2)
dataframe['Date'] = '01/'+dataframe.Month.astype(str)+'/'+dataframe.Year.astype(str)
dataframe['Date'] = pd.to_datetime(dataframe['Date'], format="%d/%m/%Y")
dataframe.drop(['Month', 'Year'],axis=1,inplace=True)

dataframe.rename(columns={'State Name': 'State', 
                            'County Name': 'County', 
                            'City Name':'City',
                            'Arithmetic Mean':'AQI_mean_ppb'}, inplace=True)

# %%
dataframe['Date'] = pd.to_datetime(dataframe['Date'], format="%d/%m/%Y")

# %%
dataframe
# Out:
#          State     County        City  AQI_mean_ppb       Date
# 0      Alabama  Jefferson  Birmingham     12.065635 2013-12-01
# 1      Alabama  Jefferson  Birmingham     12.899658 2014-01-01
# 2      Alabama  Jefferson  Birmingham      8.851034 2014-02-01
# 3      Alabama  Jefferson  Birmingham     13.212881 2014-03-01
# 4      Alabama  Jefferson  Birmingham     11.379411 2014-04-01
# ...        ...        ...         ...           ...        ...
# 42884  Wyoming     Weston   Newcastle      2.548553 2016-06-01
# 42885  Wyoming     Weston   Newcastle      2.558559 2016-07-01
# 42886  Wyoming     Weston   Newcastle      1.258537 2016-08-01
# 42887  Wyoming     Weston   Newcastle      0.539661 2016-09-01
# 42888  Wyoming     Weston   Newcastle      1.694495 2016-10-01
#
# [42889 rows x 5 columns]

# %% [markdown]
# ## Personal Income

# %%
path = '../../data/real_personal_income.csv'
dataframe = pd.read_csv(path)
dataframe = dataframe[dataframe.LineCode == 2]
dataframe.drop(['GeoFips','LineCode'],axis=1,inplace=True)

dataframe = dataframe.melt(id_vars = ['MetroArea','Description'],
                            var_name='Year', 
                            value_name='Personal Income').\
                            drop('Description',axis=1)

dataframe['Year'] = pd.to_datetime(dataframe['Year']).dt.year

dataframe.rename(columns={'MetroArea':'City'}, inplace=True)

# %%
dataframe
# Out:
#              City  Year  Personal Income
# 0          Austin  2008            44521
# 1           Miami  2008            44447
# 2        New York  2008            48585
# 3   San Francisco  2008            54862
# 4          Austin  2009            42103
# 5           Miami  2009            40469
# 6        New York  2009            46606
# 7   San Francisco  2009            52251
# 8          Austin  2010            43390
# 9           Miami  2010            42729
# 10       New York  2010            46919
# 11  San Francisco  2010            53066
# 12         Austin  2011            45502
# 13          Miami  2011            43331
# 14       New York  2011            48043
# 15  San Francisco  2011            55687
# 16         Austin  2012            47630
# 17          Miami  2012            43929
# 18       New York  2012            49407
# 19  San Francisco  2012            58278
# 20         Austin  2013            47438
# 21          Miami  2013            42196
# 22       New York  2013            49511
# 23  San Francisco  2013            57850
# 24         Austin  2014            49312
# 25          Miami  2014            44158
# 26       New York  2014            51102
# 27  San Francisco  2014            60262
# 28         Austin  2015            50350
# 29          Miami  2015            46263
# 30       New York  2015            52904
# 31  San Francisco  2015            64192
# 32         Austin  2016            50896
# 33          Miami  2016            45682
# 34       New York  2016            53694
# 35  San Francisco  2016            65860
# 36         Austin  2017            53815
# 37          Miami  2017            47723
# 38       New York  2017            55716
# 39  San Francisco  2017            67287
# 40         Austin  2018            55946
# 41          Miami  2018            49634
# 42       New York  2018            56922
# 43  San Francisco  2018            69759
# 44         Austin  2019            57297
# 45          Miami  2019            50120
# 46       New York  2019            58355
# 47  San Francisco  2019            71668

# %% [markdown]
# ##  Income Level CRC

# %%
dataframe = pd.read_csv('../../data/volume_data_Income_Level_CRC.csv')

# %%
dataframe
# Out:
#      month     date           vol     vol_unadj income_level_group
# 0       60  2005-01  1.461366e+10  1.287236e+10               High
# 1       60  2005-01  1.527169e+10  1.342024e+10             Middle
# 2       60  2005-01  4.578106e+09  3.978007e+09           Moderate
# 3       60  2005-01  7.635135e+08  6.517910e+08                Low
# 4       61  2005-02  1.433436e+10  1.272458e+10               High
# ..     ...      ...           ...           ...                ...
# 647    221  2018-06  8.982546e+08  9.167395e+08                Low
# 648    222  2018-07  1.279173e+10  1.364601e+10             Middle
# 649    222  2018-07  1.368489e+10  1.400351e+10               High
# 650    222  2018-07  4.220966e+09  4.625639e+09           Moderate
# 651    222  2018-07  8.639582e+08  9.420156e+08                Low
#
# [652 rows x 5 columns]

# %%
dataframe.drop('month', axis=1, inplace=True)
dataframe = dataframe[(dataframe['income_level_group'] != "High") & 
                        (dataframe['income_level_group'] != "Middle")]

dataframe.rename(columns={'date':'Date'}, inplace=True)

dataframe['Date'] = pd.to_datetime(dataframe['Date']+'-01', format="%Y-%m-%d")

dataframe
# Out:
# /Users/pizac/Applications/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# /Users/pizac/Applications/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#           Date           vol     vol_unadj income_level_group
# 2   2005-01-01  4.578106e+09  3.978007e+09           Moderate
# 3   2005-01-01  7.635135e+08  6.517910e+08                Low
# 6   2005-02-01  4.563908e+09  3.900504e+09           Moderate
# 7   2005-02-01  7.558710e+08  6.549358e+08                Low
# 10  2005-03-01  4.762458e+09  4.775794e+09           Moderate
# ..         ...           ...           ...                ...
# 643 2018-05-01  8.904970e+08  9.429447e+08                Low
# 646 2018-06-01  4.398129e+09  4.513570e+09           Moderate
# 647 2018-06-01  8.982546e+08  9.167395e+08                Low
# 650 2018-07-01  4.220966e+09  4.625639e+09           Moderate
# 651 2018-07-01  8.639582e+08  9.420156e+08                Low
#
# [326 rows x 4 columns]

# %% [markdown]
# ## Census

# %%
dataframe = pd.read_csv('../../data/census-query.csv',dtype={'zip_code':str})
dataframe
# Out:
#        geo_id     do_date  total_pop  households  male_pop  female_pop  \
# 0       87537  2014-01-01       2510         856      1283        1227
# 1       87017  2014-01-01        346         112       150         196
# 2       87528  2014-01-01       3505         727      1758        1747
# 3       87533  2014-01-01        133          58        49          84
# 4       87511  2014-01-01       2896         787      1177        1719
# ...       ...         ...        ...         ...       ...         ...
# 33084   35463  2014-01-01       1794         704       904         890
# 33085   77664  2014-01-01       2667         934      1300        1367
# 33086   21822  2014-01-01       2013         776      1070         943
# 33087    7418  2014-01-01       2304         766      1281        1023
# 33088    3036  2014-01-01       5039        1683      2573        2466
#
#        median_age  male_under_5  male_5_to_9  male_10_to_14  ...  \
# 0            42.1            58           75             87  ...
# 1            50.9             0            0             12  ...
# 2            27.9           260          194            159  ...
# 3            25.8             0           12              8  ...
# 4            36.0           142           63             44  ...
# ...           ...           ...          ...            ...  ...
# 33084        42.6            84           46             58  ...
# 33085        45.6            29           54            113  ...
# 33086        36.8            34           59             88  ...
# 33087        40.8            56           27             93  ...
# 33088        42.8            94          223            207  ...
#
#        sales_office_employed  in_grades_1_to_4  in_grades_5_to_8  \
# 0                        NaN               304               171
# 1                        NaN                 0                27
# 2                        NaN               293               266
# 3                        NaN                24                 8
# 4                        NaN               263               107
# ...                      ...               ...               ...
# 33084                  217.0               134                50
# 33085                  212.0                38               286
# 33086                  106.0                83               198
# 33087                  336.0                81                93
# 33088                  656.0               327               291
#
#        in_grades_9_to_12  in_school  in_undergrad_college  \
# 0                     80        593                    20
# 1                     15         96                    40
# 2                    298       1237                   138
# 3                      7         58                     3
# 4                    163       1008                   279
# ...                  ...        ...                   ...
# 33084                113        389                    50
# 33085                125        647                   171
# 33086                 40        645                   240
# 33087                292        711                   136
# 33088                202       1298                   155
#
#        speak_only_english_at_home  speak_spanish_at_home  \
# 0                             NaN                    NaN
# 1                             NaN                    NaN
# 2                             NaN                    NaN
# 3                             NaN                    NaN
# 4                             NaN                    NaN
# ...                           ...                    ...
# 33084                         NaN                    NaN
# 33085                         NaN                    NaN
# 33086                         NaN                    NaN
# 33087                         NaN                    NaN
# 33088                         NaN                    NaN
#
#        speak_spanish_at_home_low_english  zip_code
# 0                                    NaN     87537
# 1                                    NaN     87017
# 2                                    NaN     87528
# 3                                    NaN     87533
# 4                                    NaN     87511
# ...                                  ...       ...
# 33084                                NaN     35463
# 33085                                NaN     77664
# 33086                                NaN     21822
# 33087                                NaN     07418
# 33088                                NaN     03036
#
# [33089 rows x 241 columns]

# %% [markdown]
# # Transformer Function Testing

# %%
from transformers import *

zillow_path = '../../data/zillow/Zip_Zri_MultiFamilyResidenceRental.csv'
airqual_path = '../../data/airqual/' #path to folder
persinc_path = '../../data/real_personal_income.csv'
inclvl_path = '../../data/volume_data_Income_Level_CRC.csv'
census_path = '../../data/census-query.csv'

zillow_data = transform_zillow(zillow_path)
airqual_data = transform_air_qual(airqual_path)
persinc_data = transform_pers_income(persinc_path)
inclvl_data = transform_income_level(inclvl_path)
census_data = transform_census(census_path)

# %%
zillow_data.head()
# Out:
#        RegionID Zipcode      City State                             Metro  \
# 96772     61639   10025  New York    NY       New York-Newark-Jersey City
# 96773     84654   60657   Chicago    IL          Chicago-Naperville-Elgin
# 96774     61637   10023  New York    NY       New York-Newark-Jersey City
# 96775     91982   77494      Katy    TX  Houston-The Woodlands-Sugar Land
# 96776     84616   60614   Chicago    IL          Chicago-Naperville-Elgin
#
#                 County  SizeRank       Date    Rent  Year
# 96772  New York County         1 2015-01-01  3566.0  2015
# 96773      Cook County         2 2015-01-01  1672.0  2015
# 96774  New York County         3 2015-01-01  3413.0  2015
# 96775    Harris County         4 2015-01-01  1137.0  2015
# 96776      Cook County         5 2015-01-01  1822.0  2015

# %%
airqual_data.head()
# Out:
#      State     County        City    AQIMean       Date
# 0  Alabama  Jefferson  Birmingham  12.065635 2013-12-01
# 1  Alabama  Jefferson  Birmingham  12.899658 2014-01-01
# 2  Alabama  Jefferson  Birmingham   8.851034 2014-02-01
# 3  Alabama  Jefferson  Birmingham  13.212881 2014-03-01
# 4  Alabama  Jefferson  Birmingham  11.379411 2014-04-01

# %%
persinc_data.head()
# Out:
#   State  Year  PersonalIncome
# 0    TX  2008           44521
# 1    FL  2008           44447
# 2    NY  2008           48585
# 3    CA  2008           54862
# 4    TX  2009           42103

# %%
inclvl_data.head()

# %%
census_data.head()

# %% [markdown]
# ## merging data to one master csv

# %%
rent_data = zillow_data.merge(persinc_data,left_on = ['State','Year'],
                             right_on = ['State','Year'])

# %%
airqual_data['County'] = airqual_data['County'].apply(lambda County: County + ' County')
airqual_data.drop('State',axis = 1, inplace = True)
rent_data = rent_data.merge(airqual_data,on = ['County','Date','City'],how = 'left')
rent_data.head()
# Out:
#    RegionID Zipcode      City State                        Metro  \
# 0     61639   10025  New York    NY  New York-Newark-Jersey City
# 1     61637   10023  New York    NY  New York-Newark-Jersey City
# 2     61616   10002  New York    NY  New York-Newark-Jersey City
# 3     62037   11226  New York    NY  New York-Newark-Jersey City
# 4     61807   10467  New York    NY  New York-Newark-Jersey City
#
#             County  SizeRank       Date    Rent  Year  PersonalIncome  \
# 0  New York County         1 2015-01-01  3566.0  2015           52904
# 1  New York County         3 2015-01-01  3413.0  2015           52904
# 2  New York County         7 2015-01-01  3508.0  2015           52904
# 3     Kings County        11 2015-01-01  1876.0  2015           52904
# 4     Bronx County        12 2015-01-01  1442.0  2015           52904
#
#     AQIMean
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4  22.97755

# %%
rent_data = rent_data.merge(inclvl_data,how = 'left',on = 'Date')

# %%
rent_data.sample(15)
# Out:
#        RegionID Zipcode               City State  \
# 18502     61790   10314           New York    NY
# 25782     72236   32810            Orlando    FL
# 14099     97837   94703           Berkeley    CA
# 26005     72163   32714  Altamonte Springs    FL
# 35577     61805   10465           New York    NY
# 41026     97991   95123           San Jose    CA
# 10614     61805   10465           New York    NY
# 27449     62479   12209             Albany    NY
# 28070     63472   14215            Buffalo    NY
# 42919     72488   33186      The Crossings    FL
# 17562     62033   11222           New York    NY
# 5207      96974   92656        Aliso Viejo    CA
# 30597     90630   75025              Plano    TX
# 14423     96510   91770           Rosemead    CA
# 21624     90800   75248             Dallas    TX
#
#                                        Metro              County  SizeRank  \
# 18502            New York-Newark-Jersey City     Richmond County       111
# 25782              Orlando-Kissimmee-Sanford       Orange County      1122
# 14099          San Francisco-Oakland-Hayward      Alameda County      1571
# 26005              Orlando-Kissimmee-Sanford     Seminole County       788
# 35577            New York-Newark-Jersey City        Bronx County      1171
# 41026         San Jose-Sunnyvale-Santa Clara  Santa Clara County       186
# 10614            New York-Newark-Jersey City        Bronx County      1171
# 27449                Albany-Schenectady-Troy       Albany County      1830
# 28070      Buffalo-Cheektowaga-Niagara Falls         Erie County       951
# 42919  Miami-Fort Lauderdale-West Palm Beach   Miami-Dade County       182
# 17562            New York-Newark-Jersey City        Kings County       597
# 5207          Los Angeles-Long Beach-Anaheim       Orange County       427
# 30597            Dallas-Fort Worth-Arlington       Collin County       481
# 14423         Los Angeles-Long Beach-Anaheim  Los Angeles County       655
# 21624            Dallas-Fort Worth-Arlington       Dallas County       615
#
#             Date    Rent  Year  PersonalIncome    AQIMean  \
# 18502 2017-05-01  1805.0  2017           55716        NaN
# 25782 2017-09-01  1253.0  2017           47723        NaN
# 14099 2016-04-01  2818.0  2016           65860        NaN
# 26005 2017-11-01  1177.0  2017           47723        NaN
# 35577 2019-03-01  1948.0  2019           58355  18.342488
# 41026 2019-08-01  2816.0  2019           71668   8.668130
# 10614 2016-08-01  1694.0  2016           53694  12.477284
# 27449 2018-05-01  1150.0  2018           56922        NaN
# 28070 2018-08-01   780.0  2018           56922   7.020057
# 42919 2019-07-01  1607.0  2019           50120        NaN
# 17562 2017-01-01  2728.0  2017           55716        NaN
# 5207  2015-04-01  1925.0  2015           64192        NaN
# 30597 2018-12-01  1378.0  2018           55946        NaN
# 14423 2016-06-01  2964.0  2016           65860        NaN
# 21624 2017-10-01  1302.0  2017           53815   8.314109
#
#        Vol_moderate_income  Vol_low_income
# 18502         4.194065e+09    8.285685e+08
# 25782         4.193447e+09    8.564680e+08
# 14099         4.656035e+09    9.457059e+08
# 26005         4.391051e+09    9.430037e+08
# 35577                  NaN             NaN
# 41026                  NaN             NaN
# 10614         4.729561e+09    9.703671e+08
# 27449         4.571036e+09    8.904970e+08
# 28070                  NaN             NaN
# 42919                  NaN             NaN
# 17562         4.900730e+09    1.108420e+09
# 5207          4.049018e+09    8.337951e+08
# 30597                  NaN             NaN
# 14423         4.751104e+09    9.758423e+08
# 21624         4.343624e+09    8.284113e+08

# %%
rent_data = pd.merge(rent_data, census_data, how = 'left', on = 'Zipcode')

# %%
rent_data.shape
# Out:
# (43680, 254)

# %%
rent_data.dtypes
# Out:
# RegionID                               int64
# Zipcode                               object
# City                                  object
# State                                 object
# Metro                                 object
#                                       ...
# in_school                            float64
# in_undergrad_college                 float64
# speak_only_english_at_home           float64
# speak_spanish_at_home                float64
# speak_spanish_at_home_low_english    float64
# Length: 254, dtype: object

# %%
rent_data.to_csv('../../data/rent_data.csv',index = False)
